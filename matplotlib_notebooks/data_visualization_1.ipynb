# %%
import matplotlib.pyplot as plt

# %%
age=[25,27,29,31,33,35,37,39,41,43,45] # list(range(25,46,2))


salary=[38476, 42000, 46752,49320,53200,56000,62316,64928,67317,68748,73752]

# %%
# Out:
# [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]

# %%
plt.plot(age,salary)
plt.xlabel('age')
plt.ylabel('salary')
plt.title('Salary by Age')
plt.show()

# %%
salary2=[45372,48876,53850,57287,63016,65998,70003,70000,75370,83640]

# %%
plt.plot(age,salary)
plt.plot(age,salary2)

plt.xlabel('age')
plt.ylabel('salary')
plt.title('Salary by Age')
plt.show()
