# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
age=[25,27,29,31,33,35,37,39,41,43,45]
salary=[38496,42000,46752,49320,53200,56000,62316,64928,67317,68748,73752]
salary_2=[45372,48876,53850,57287,63016,65998,70003,70000,71496,75370,83640]

# %%
df=pd.DataFrame(list(zip(age,salary, salary_2)), columns=['age','salary', 'salary_2'])

# %%
df.head()
# Out:
#    age  salary  salary_2
# 0   25   38496     45372
# 1   27   42000     48876
# 2   29   46752     53850
# 3   31   49320     57287
# 4   33   53200     63016

# %%
fig=plt.figure(figsize=(8,4))#axes te bir ekleme degisiklik vs yapilmayacaksa boyle olusturulabilir.
#Buradaki (8,4) inch cinsinden ebatlar, vermezsek default (6.4,4.8)

# %%
fig,ax=plt.subplots(figsize=(6,3))#Bu yontem her turlu calisir, daha cok bunu kullanacagiz.
ax.plot(age,salary,'r')
ax.set_xlabel('age')
ax.set_ylabel('salary')
ax.set_title('Ages with Salary')
# Out:
# Text(0.5, 1.0, 'Ages with Salary')

# %%
fig.savefig('myplot.png', dpi=100)#jpeg veya pdf olarak da kaydedilebilir.

# %%
fig,ax=plt.subplots(figsize=(8,3))#Bu yontem her turlu calisir, daha cok bunu kullanacagiz.
ax.plot(age,salary,'r', label='salary_1', lw=4, ls='-.', marker='o', ms=10, markerfacecolor='b', alpha=0.3)
ax.set_xlabel('age')
ax.set_ylabel('salary')
ax.set_title('Ages with Salary')
ax.legend()

# %%
#PLOT RANGE
fig,ax=plt.subplots(figsize=(8,4))
ax.plot(age,salary)
ax.set_xlim([30,40])#Belli bir alana odaklanmak icin xlim ve ylim atayabiliyoruz.
ax.set_ylim([45000,60000])
#Adding vertical-horizantal lines
ax.axvline(x=35, color='green', ls='--')
ax.axhline(y=52000, color='orange')

# %%
# Bar Plot
country=['UK','USA','FRA', 'GER', 'NOR']
pci=[40000,50000,38000,55000,80000]

# %%
fig,ax=plt.subplots()
ax.bar(country, pci)
ax.set_xlabel('country')
ax.set_ylabel('pci')
ax.set_title('pci per country')
# Out:
# Text(0.5, 1.0, 'pci per country')

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
fig,ax=plt.subplots()
ax.bar(labels,men_means);

# %%
fig,ax=plt.subplots()
x = np.arange(len(labels))  # the label locations
#Yukaridaki satir standart boyle yazilir, x lerin yeri belirlenir
width = 0.35  # the width of the bars

rects1=ax.bar(x - width/2, men_means, width, label='Men')# x - width/2 bu kisim ile x eksenindeki yerini ayarliyoruz.
#Yoksa ust uste biner iki plot
rects2=ax.bar(x + width/2, women_means, width, label='Women')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend();

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
rects1
# Out:
# <BarContainer object of 5 artists>

# %%
rects1[0]

# %%
print(rects1[0])
# Out:
# Rectangle(xy=(-0.35, 0), width=0.35, height=20, angle=0)

# %%
rects1[0].get_height()
# Out:
# 20

# %%
rects1[0].get_width()
# Out:
# 0.35

# %%
rects1[0].get_xy()
# Out:
# (-0.35, 0)

# %%
rects1[0].get_x()
# Out:
# -0.35

# %% [markdown]
# # To do the same plot with Pandas

# %%
import pandas as pd 
df=pd.DataFrame(list(zip(labels,men_means, women_means)), columns=['labels','men', 'women'])
df.head()
# Out:
#   labels  men  women
# 0     G1   20     25
# 1     G2   34     32
# 2     G3   30     34
# 3     G4   35     20
# 4     G5   27     25

# %%
ax=df.plot.bar(rot=0, figsize=(10,6))#Sadece bu satir bile yeterli pandas ile cizdirmek icin, alt satirlar detay
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.axhline(y=20,color='green',ls='--')

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.5))

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
df.plot.bar('labels', rot=0,stacked='True');#Yukaridaki ayni kodun pandas ile yazilmis hali bu kadar kisa, tek satir

# %%
df.plot.barh('labels', rot=0,stacked='True')
