# %%
import bs4
import urllib3
import re
#!pip3 install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk import sent_tokenize
from nltk.corpus import stopwords
from nltk import word_tokenize
stop_word = stopwords.words('english')
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/enginkosure/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/enginkosure/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
url_name = input("Enter url of the text you want to summerize:")
# Out:
# Enter url of the text you want to summerize:https://towardsdatascience.com/building-a-simple-ui-for-python-fd0e5f2a2d8b

# %%
http = urllib3.PoolManager()
response = http.request('GET', url_name)

page = bs4.BeautifulSoup(response.data)
elements = page.find_all('p')
article = ''
for i in elements:
    article+= (i.text)
article
# Out:
# /Users/enginkosure/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/enginkosure/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/enginkosure/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 'Showcasing a Python project with a user interface has never been easier. With the Streamlit framework you can build a browser-based UI using only Python code. In this demo, we will be building the UI for a maze solver program described in detail in a previous article.Streamlit is a web framework intended for data scientists to easily deploy models and visualizations using Python. It is fast and minimalistic but also pretty and user-friendly. There are built-in widgets for user input like image-uploading, sliders, text input, and other familiar HTML elements like checkboxes and radio buttons. Whenever a user interacts with the streamlit application, the python script is re-run from top to bottom, an important concept to keep in mind when considering different states of your app.You can install Streamlit with pip:And run streamlit on a python script:In the previous demo, we built a Python program that will solve a maze given an image file and starting/ending locations. We would like to turn this program into a single-page web app where a user can upload a maze image (or use a default maze image), adjust the maze start and end locations, and see the final solved maze.First, let’s create the UI for the image uploader and the option to use a default image. We can add text outputs using functions like st.write() or st.title(). We store a dynamically uploaded file using streamlit’s st.file_uploader() function. Finally, st.checkbox() will return a boolean based on whether the user has selected the checkbox.The result:We can then read our default or uploaded image into a usable OpenCV image format.Once an image is uploaded, we want to show the image marked up with starting and ending points. We will use sliders to allow the user to reposition these points. The st.sidebar() function adds a sidebar to the page and st.slider() takes numerical input within a defined minimum and maximum. We can define slider minimum and maximum values dynamically based on the size of our maze image.Whenever the user adjusts the sliders, the image is quickly re-rendered and the points change position.Once the user has finalized the start and end positions, we want a button to solve the maze and display the solution. The st.spinner() element is displayed only while its child process is running, and the st.image() call is used to display an image.In less than 40 lines of code we have created a simple UI for a Python image processing app. We did not need to write any traditional front-end code. Besides Streamlit’s ability to digest simple Python code, Streamlit intelligently re-runs the necessary parts of your script from top to bottom whenever the user interacts with the page or the script is changed. This allows for straightforward data flow and rapid development.You can find the full code on Github and Part 1 explaining the algorithm behind the maze solver here. Streamlit documentation including important concepts and additional widgets is located here.Hands-on real-world examples, research,  tutorials, and cutting-edge techniques delivered Monday to Thursday. Make learning your daily ritual.\xa0Take a lookCreate a free Medium account to get The Daily Pick in your inbox.Written byWritten by'

# %%
processed = article.replace(r'^\s+|\s+?$','')
processed = processed.replace('\n',' ')
processed = processed.replace("\\",'')
processed = processed.replace(",",'')
processed = processed.replace('"','')
processed = re.sub(r'\[[0-9]*\]','',processed)
processed
# Out:
# 'Showcasing a Python project with a user interface has never been easier. With the Streamlit framework you can build a browser-based UI using only Python code. In this demo we will be building the UI for a maze solver program described in detail in a previous article.Streamlit is a web framework intended for data scientists to easily deploy models and visualizations using Python. It is fast and minimalistic but also pretty and user-friendly. There are built-in widgets for user input like image-uploading sliders text input and other familiar HTML elements like checkboxes and radio buttons. Whenever a user interacts with the streamlit application the python script is re-run from top to bottom an important concept to keep in mind when considering different states of your app.You can install Streamlit with pip:And run streamlit on a python script:In the previous demo we built a Python program that will solve a maze given an image file and starting/ending locations. We would like to turn this program into a single-page web app where a user can upload a maze image (or use a default maze image) adjust the maze start and end locations and see the final solved maze.First let’s create the UI for the image uploader and the option to use a default image. We can add text outputs using functions like st.write() or st.title(). We store a dynamically uploaded file using streamlit’s st.file_uploader() function. Finally st.checkbox() will return a boolean based on whether the user has selected the checkbox.The result:We can then read our default or uploaded image into a usable OpenCV image format.Once an image is uploaded we want to show the image marked up with starting and ending points. We will use sliders to allow the user to reposition these points. The st.sidebar() function adds a sidebar to the page and st.slider() takes numerical input within a defined minimum and maximum. We can define slider minimum and maximum values dynamically based on the size of our maze image.Whenever the user adjusts the sliders the image is quickly re-rendered and the points change position.Once the user has finalized the start and end positions we want a button to solve the maze and display the solution. The st.spinner() element is displayed only while its child process is running and the st.image() call is used to display an image.In less than 40 lines of code we have created a simple UI for a Python image processing app. We did not need to write any traditional front-end code. Besides Streamlit’s ability to digest simple Python code Streamlit intelligently re-runs the necessary parts of your script from top to bottom whenever the user interacts with the page or the script is changed. This allows for straightforward data flow and rapid development.You can find the full code on Github and Part 1 explaining the algorithm behind the maze solver here. Streamlit documentation including important concepts and additional widgets is located here.Hands-on real-world examples research  tutorials and cutting-edge techniques delivered Monday to Thursday. Make learning your daily ritual.\xa0Take a lookCreate a free Medium account to get The Daily Pick in your inbox.Written byWritten by'

# %%
sentences = sent_tokenize(processed)

# %%
frequency = {}
processed1 = processed.lower()
for word in word_tokenize(processed1):
    if word not in stop_word and word not in string.punctuation:
        if word not in frequency.keys():
            frequency[word]=1
        else:
            frequency[word]+=1
frequency
# Out:
# {'showcasing': 1,
#  'python': 8,
#  'project': 1,
#  'user': 9,
#  'interface': 1,
#  'never': 1,
#  'easier': 1,
#  'streamlit': 8,
#  'framework': 2,
#  'build': 1,
#  'browser-based': 1,
#  'ui': 4,
#  'using': 4,
#  'code': 5,
#  'demo': 2,
#  'building': 1,
#  'maze': 8,
#  'solver': 2,
#  'program': 3,
#  'described': 1,
#  'detail': 1,
#  'previous': 2,
#  'article.streamlit': 1,
#  'web': 2,
#  'intended': 1,
#  'data': 2,
#  'scientists': 1,
#  'easily': 1,
#  'deploy': 1,
#  'models': 1,
#  'visualizations': 1,
#  'fast': 1,
#  'minimalistic': 1,
#  'also': 1,
#  'pretty': 1,
#  'user-friendly': 1,
#  'built-in': 1,
#  'widgets': 2,
#  'input': 3,
#  'like': 4,
#  'image-uploading': 1,
#  'sliders': 3,
#  'text': 2,
#  'familiar': 1,
#  'html': 1,
#  'elements': 1,
#  'checkboxes': 1,
#  'radio': 1,
#  'buttons': 1,
#  'whenever': 2,
#  'interacts': 2,
#  'application': 1,
#  'script': 4,
#  're-run': 1,
#  'top': 2,
#  'bottom': 2,
#  'important': 2,
#  'concept': 1,
#  'keep': 1,
#  'mind': 1,
#  'considering': 1,
#  'different': 1,
#  'states': 1,
#  'app.you': 1,
#  'install': 1,
#  'pip': 1,
#  'run': 1,
#  'built': 1,
#  'solve': 2,
#  'given': 1,
#  'image': 11,
#  'file': 2,
#  'starting/ending': 1,
#  'locations': 2,
#  'would': 1,
#  'turn': 1,
#  'single-page': 1,
#  'app': 2,
#  'upload': 1,
#  'use': 3,
#  'default': 3,
#  'adjust': 1,
#  'start': 2,
#  'end': 2,
#  'see': 1,
#  'final': 1,
#  'solved': 1,
#  'maze.first': 1,
#  'let': 1,
#  '’': 3,
#  'create': 1,
#  'uploader': 1,
#  'option': 1,
#  'add': 1,
#  'outputs': 1,
#  'functions': 1,
#  'st.write': 1,
#  'st.title': 1,
#  'store': 1,
#  'dynamically': 2,
#  'uploaded': 3,
#  'st.file_uploader': 1,
#  'function': 2,
#  'finally': 1,
#  'st.checkbox': 1,
#  'return': 1,
#  'boolean': 1,
#  'based': 2,
#  'whether': 1,
#  'selected': 1,
#  'checkbox.the': 1,
#  'result': 1,
#  'read': 1,
#  'usable': 1,
#  'opencv': 1,
#  'format.once': 1,
#  'want': 2,
#  'show': 1,
#  'marked': 1,
#  'starting': 1,
#  'ending': 1,
#  'points': 3,
#  'allow': 1,
#  'reposition': 1,
#  'st.sidebar': 1,
#  'adds': 1,
#  'sidebar': 1,
#  'page': 2,
#  'st.slider': 1,
#  'takes': 1,
#  'numerical': 1,
#  'within': 1,
#  'defined': 1,
#  'minimum': 2,
#  'maximum': 2,
#  'define': 1,
#  'slider': 1,
#  'values': 1,
#  'size': 1,
#  'image.whenever': 1,
#  'adjusts': 1,
#  'quickly': 1,
#  're-rendered': 1,
#  'change': 1,
#  'position.once': 1,
#  'finalized': 1,
#  'positions': 1,
#  'button': 1,
#  'display': 2,
#  'solution': 1,
#  'st.spinner': 1,
#  'element': 1,
#  'displayed': 1,
#  'child': 1,
#  'process': 1,
#  'running': 1,
#  'st.image': 1,
#  'call': 1,
#  'used': 1,
#  'image.in': 1,
#  'less': 1,
#  '40': 1,
#  'lines': 1,
#  'created': 1,
#  'simple': 2,
#  'processing': 1,
#  'need': 1,
#  'write': 1,
#  'traditional': 1,
#  'front-end': 1,
#  'besides': 1,
#  'ability': 1,
#  'digest': 1,
#  'intelligently': 1,
#  're-runs': 1,
#  'necessary': 1,
#  'parts': 1,
#  'changed': 1,
#  'allows': 1,
#  'straightforward': 1,
#  'flow': 1,
#  'rapid': 1,
#  'development.you': 1,
#  'find': 1,
#  'full': 1,
#  'github': 1,
#  'part': 1,
#  '1': 1,
#  'explaining': 1,
#  'algorithm': 1,
#  'behind': 1,
#  'documentation': 1,
#  'including': 1,
#  'concepts': 1,
#  'additional': 1,
#  'located': 1,
#  'here.hands-on': 1,
#  'real-world': 1,
#  'examples': 1,
#  'research': 1,
#  'tutorials': 1,
#  'cutting-edge': 1,
#  'techniques': 1,
#  'delivered': 1,
#  'monday': 1,
#  'thursday': 1,
#  'make': 1,
#  'learning': 1,
#  'daily': 2,
#  'ritual': 1,
#  'take': 1,
#  'lookcreate': 1,
#  'free': 1,
#  'medium': 1,
#  'account': 1,
#  'get': 1,
#  'pick': 1,
#  'inbox.written': 1,
#  'bywritten': 1}

# %%
max_fre = max(frequency.values())
for word in frequency.keys():
    frequency[word]=(frequency[word]/max_fre)
frequency
# Out:
# {'showcasing': 0.09090909090909091,
#  'python': 0.7272727272727273,
#  'project': 0.09090909090909091,
#  'user': 0.8181818181818182,
#  'interface': 0.09090909090909091,
#  'never': 0.09090909090909091,
#  'easier': 0.09090909090909091,
#  'streamlit': 0.7272727272727273,
#  'framework': 0.18181818181818182,
#  'build': 0.09090909090909091,
#  'browser-based': 0.09090909090909091,
#  'ui': 0.36363636363636365,
#  'using': 0.36363636363636365,
#  'code': 0.45454545454545453,
#  'demo': 0.18181818181818182,
#  'building': 0.09090909090909091,
#  'maze': 0.7272727272727273,
#  'solver': 0.18181818181818182,
#  'program': 0.2727272727272727,
#  'described': 0.09090909090909091,
#  'detail': 0.09090909090909091,
#  'previous': 0.18181818181818182,
#  'article.streamlit': 0.09090909090909091,
#  'web': 0.18181818181818182,
#  'intended': 0.09090909090909091,
#  'data': 0.18181818181818182,
#  'scientists': 0.09090909090909091,
#  'easily': 0.09090909090909091,
#  'deploy': 0.09090909090909091,
#  'models': 0.09090909090909091,
#  'visualizations': 0.09090909090909091,
#  'fast': 0.09090909090909091,
#  'minimalistic': 0.09090909090909091,
#  'also': 0.09090909090909091,
#  'pretty': 0.09090909090909091,
#  'user-friendly': 0.09090909090909091,
#  'built-in': 0.09090909090909091,
#  'widgets': 0.18181818181818182,
#  'input': 0.2727272727272727,
#  'like': 0.36363636363636365,
#  'image-uploading': 0.09090909090909091,
#  'sliders': 0.2727272727272727,
#  'text': 0.18181818181818182,
#  'familiar': 0.09090909090909091,
#  'html': 0.09090909090909091,
#  'elements': 0.09090909090909091,
#  'checkboxes': 0.09090909090909091,
#  'radio': 0.09090909090909091,
#  'buttons': 0.09090909090909091,
#  'whenever': 0.18181818181818182,
#  'interacts': 0.18181818181818182,
#  'application': 0.09090909090909091,
#  'script': 0.36363636363636365,
#  're-run': 0.09090909090909091,
#  'top': 0.18181818181818182,
#  'bottom': 0.18181818181818182,
#  'important': 0.18181818181818182,
#  'concept': 0.09090909090909091,
#  'keep': 0.09090909090909091,
#  'mind': 0.09090909090909091,
#  'considering': 0.09090909090909091,
#  'different': 0.09090909090909091,
#  'states': 0.09090909090909091,
#  'app.you': 0.09090909090909091,
#  'install': 0.09090909090909091,
#  'pip': 0.09090909090909091,
#  'run': 0.09090909090909091,
#  'built': 0.09090909090909091,
#  'solve': 0.18181818181818182,
#  'given': 0.09090909090909091,
#  'image': 1.0,
#  'file': 0.18181818181818182,
#  'starting/ending': 0.09090909090909091,
#  'locations': 0.18181818181818182,
#  'would': 0.09090909090909091,
#  'turn': 0.09090909090909091,
#  'single-page': 0.09090909090909091,
#  'app': 0.18181818181818182,
#  'upload': 0.09090909090909091,
#  'use': 0.2727272727272727,
#  'default': 0.2727272727272727,
#  'adjust': 0.09090909090909091,
#  'start': 0.18181818181818182,
#  'end': 0.18181818181818182,
#  'see': 0.09090909090909091,
#  'final': 0.09090909090909091,
#  'solved': 0.09090909090909091,
#  'maze.first': 0.09090909090909091,
#  'let': 0.09090909090909091,
#  '’': 0.2727272727272727,
#  'create': 0.09090909090909091,
#  'uploader': 0.09090909090909091,
#  'option': 0.09090909090909091,
#  'add': 0.09090909090909091,
#  'outputs': 0.09090909090909091,
#  'functions': 0.09090909090909091,
#  'st.write': 0.09090909090909091,
#  'st.title': 0.09090909090909091,
#  'store': 0.09090909090909091,
#  'dynamically': 0.18181818181818182,
#  'uploaded': 0.2727272727272727,
#  'st.file_uploader': 0.09090909090909091,
#  'function': 0.18181818181818182,
#  'finally': 0.09090909090909091,
#  'st.checkbox': 0.09090909090909091,
#  'return': 0.09090909090909091,
#  'boolean': 0.09090909090909091,
#  'based': 0.18181818181818182,
#  'whether': 0.09090909090909091,
#  'selected': 0.09090909090909091,
#  'checkbox.the': 0.09090909090909091,
#  'result': 0.09090909090909091,
#  'read': 0.09090909090909091,
#  'usable': 0.09090909090909091,
#  'opencv': 0.09090909090909091,
#  'format.once': 0.09090909090909091,
#  'want': 0.18181818181818182,
#  'show': 0.09090909090909091,
#  'marked': 0.09090909090909091,
#  'starting': 0.09090909090909091,
#  'ending': 0.09090909090909091,
#  'points': 0.2727272727272727,
#  'allow': 0.09090909090909091,
#  'reposition': 0.09090909090909091,
#  'st.sidebar': 0.09090909090909091,
#  'adds': 0.09090909090909091,
#  'sidebar': 0.09090909090909091,
#  'page': 0.18181818181818182,
#  'st.slider': 0.09090909090909091,
#  'takes': 0.09090909090909091,
#  'numerical': 0.09090909090909091,
#  'within': 0.09090909090909091,
#  'defined': 0.09090909090909091,
#  'minimum': 0.18181818181818182,
#  'maximum': 0.18181818181818182,
#  'define': 0.09090909090909091,
#  'slider': 0.09090909090909091,
#  'values': 0.09090909090909091,
#  'size': 0.09090909090909091,
#  'image.whenever': 0.09090909090909091,
#  'adjusts': 0.09090909090909091,
#  'quickly': 0.09090909090909091,
#  're-rendered': 0.09090909090909091,
#  'change': 0.09090909090909091,
#  'position.once': 0.09090909090909091,
#  'finalized': 0.09090909090909091,
#  'positions': 0.09090909090909091,
#  'button': 0.09090909090909091,
#  'display': 0.18181818181818182,
#  'solution': 0.09090909090909091,
#  'st.spinner': 0.09090909090909091,
#  'element': 0.09090909090909091,
#  'displayed': 0.09090909090909091,
#  'child': 0.09090909090909091,
#  'process': 0.09090909090909091,
#  'running': 0.09090909090909091,
#  'st.image': 0.09090909090909091,
#  'call': 0.09090909090909091,
#  'used': 0.09090909090909091,
#  'image.in': 0.09090909090909091,
#  'less': 0.09090909090909091,
#  '40': 0.09090909090909091,
#  'lines': 0.09090909090909091,
#  'created': 0.09090909090909091,
#  'simple': 0.18181818181818182,
#  'processing': 0.09090909090909091,
#  'need': 0.09090909090909091,
#  'write': 0.09090909090909091,
#  'traditional': 0.09090909090909091,
#  'front-end': 0.09090909090909091,
#  'besides': 0.09090909090909091,
#  'ability': 0.09090909090909091,
#  'digest': 0.09090909090909091,
#  'intelligently': 0.09090909090909091,
#  're-runs': 0.09090909090909091,
#  'necessary': 0.09090909090909091,
#  'parts': 0.09090909090909091,
#  'changed': 0.09090909090909091,
#  'allows': 0.09090909090909091,
#  'straightforward': 0.09090909090909091,
#  'flow': 0.09090909090909091,
#  'rapid': 0.09090909090909091,
#  'development.you': 0.09090909090909091,
#  'find': 0.09090909090909091,
#  'full': 0.09090909090909091,
#  'github': 0.09090909090909091,
#  'part': 0.09090909090909091,
#  '1': 0.09090909090909091,
#  'explaining': 0.09090909090909091,
#  'algorithm': 0.09090909090909091,
#  'behind': 0.09090909090909091,
#  'documentation': 0.09090909090909091,
#  'including': 0.09090909090909091,
#  'concepts': 0.09090909090909091,
#  'additional': 0.09090909090909091,
#  'located': 0.09090909090909091,
#  'here.hands-on': 0.09090909090909091,
#  'real-world': 0.09090909090909091,
#  'examples': 0.09090909090909091,
#  'research': 0.09090909090909091,
#  'tutorials': 0.09090909090909091,
#  'cutting-edge': 0.09090909090909091,
#  'techniques': 0.09090909090909091,
#  'delivered': 0.09090909090909091,
#  'monday': 0.09090909090909091,
#  'thursday': 0.09090909090909091,
#  'make': 0.09090909090909091,
#  'learning': 0.09090909090909091,
#  'daily': 0.18181818181818182,
#  'ritual': 0.09090909090909091,
#  'take': 0.09090909090909091,
#  'lookcreate': 0.09090909090909091,
#  'free': 0.09090909090909091,
#  'medium': 0.09090909090909091,
#  'account': 0.09090909090909091,
#  'get': 0.09090909090909091,
#  'pick': 0.09090909090909091,
#  'inbox.written': 0.09090909090909091,
#  'bywritten': 0.09090909090909091}

# %%
sentence_score = {}
for sent in sentences:
    for word in word_tokenize(sent):
        if word in frequency.keys():
            if len(sent.split(' '))<30:
                if sent not in sentence_score.keys():
                    sentence_score[sent] = frequency[word]
                else:
                    sentence_score[sent]+=frequency[word]
sentence_score
# Out:
# {'Showcasing a Python project with a user interface has never been easier.': 1.1818181818181817,
#  'With the Streamlit framework you can build a browser-based UI using only Python code.': 1.1818181818181819,
#  'It is fast and minimalistic but also pretty and user-friendly.': 0.4545454545454546,
#  'There are built-in widgets for user input like image-uploading sliders text input and other familiar HTML elements like checkboxes and radio buttons.': 3.363636363636363,
#  'We can add text outputs using functions like st.write() or st.title().': 1.3636363636363635,
#  'We store a dynamically uploaded file using streamlit’s st.file_uploader() function.': 2.3636363636363633,
#  'We will use sliders to allow the user to reposition these points.': 1.8181818181818181,
#  'The st.sidebar() function adds a sidebar to the page and st.slider() takes numerical input within a defined minimum and maximum.': 1.7272727272727275,
#  'We did not need to write any traditional front-end code.': 0.8181818181818181,
#  'This allows for straightforward data flow and rapid development.You can find the full code on Github and Part 1 explaining the algorithm behind the maze solver here.': 2.454545454545454,
#  'Streamlit documentation including important concepts and additional widgets is located here.Hands-on real-world examples research  tutorials and cutting-edge techniques delivered Monday to Thursday.': 1.4545454545454541,
#  'Make learning your daily ritual.': 0.36363636363636365,
#  'Take a lookCreate a free Medium account to get The Daily Pick in your inbox.Written byWritten by': 0.2727272727272727}

# %%
import heapq
summary = heapq.nlargest(4,sentence_score,key = sentence_score.get)
summary = ' '.join(summary)
final = "SUMMARY:- \n  " +summary
textfinal = 'TEXT:-    '+processed
textfinal = textfinal.encode('ascii','ignore')
textfinal = str(textfinal) 
final
# Out:
# 'SUMMARY:- \n  There are built-in widgets for user input like image-uploading sliders text input and other familiar HTML elements like checkboxes and radio buttons. This allows for straightforward data flow and rapid development.You can find the full code on Github and Part 1 explaining the algorithm behind the maze solver here. We store a dynamically uploaded file using streamlit’s st.file_uploader() function. We will use sliders to allow the user to reposition these points.'

# %%
textfinal
# Out:
# "b'TEXT:-    Showcasing a Python project with a user interface has never been easier. With the Streamlit framework you can build a browser-based UI using only Python code. In this demo we will be building the UI for a maze solver program described in detail in a previous article.Streamlit is a web framework intended for data scientists to easily deploy models and visualizations using Python. It is fast and minimalistic but also pretty and user-friendly. There are built-in widgets for user input like image-uploading sliders text input and other familiar HTML elements like checkboxes and radio buttons. Whenever a user interacts with the streamlit application the python script is re-run from top to bottom an important concept to keep in mind when considering different states of your app.You can install Streamlit with pip:And run streamlit on a python script:In the previous demo we built a Python program that will solve a maze given an image file and starting/ending locations. We would like to turn this program into a single-page web app where a user can upload a maze image (or use a default maze image) adjust the maze start and end locations and see the final solved maze.First lets create the UI for the image uploader and the option to use a default image. We can add text outputs using functions like st.write() or st.title(). We store a dynamically uploaded file using streamlits st.file_uploader() function. Finally st.checkbox() will return a boolean based on whether the user has selected the checkbox.The result:We can then read our default or uploaded image into a usable OpenCV image format.Once an image is uploaded we want to show the image marked up with starting and ending points. We will use sliders to allow the user to reposition these points. The st.sidebar() function adds a sidebar to the page and st.slider() takes numerical input within a defined minimum and maximum. We can define slider minimum and maximum values dynamically based on the size of our maze image.Whenever the user adjusts the sliders the image is quickly re-rendered and the points change position.Once the user has finalized the start and end positions we want a button to solve the maze and display the solution. The st.spinner() element is displayed only while its child process is running and the st.image() call is used to display an image.In less than 40 lines of code we have created a simple UI for a Python image processing app. We did not need to write any traditional front-end code. Besides Streamlits ability to digest simple Python code Streamlit intelligently re-runs the necessary parts of your script from top to bottom whenever the user interacts with the page or the script is changed. This allows for straightforward data flow and rapid development.You can find the full code on Github and Part 1 explaining the algorithm behind the maze solver here. Streamlit documentation including important concepts and additional widgets is located here.Hands-on real-world examples research  tutorials and cutting-edge techniques delivered Monday to Thursday. Make learning your daily ritual.Take a lookCreate a free Medium account to get The Daily Pick in your inbox.Written byWritten by'"
