# %%
import numpy as np
from scipy import stats

# %%
age=[20,22,25,25,27,27,27,29,30,31,121]
np.mean(age)
# Out:
# 34.90909090909091

# %%
np.median(age)
# Out:
# 27.0

# %%
stats.mode(age)
# Out:
# ModeResult(mode=array([27]), count=array([3]))

# %%
stats.mode(age)[0][0]#Bu sekilde sadece sayi elde edilip bir degiskene atanabilir.
# Out:
# 27

# %%
age_2=[19,18,17,20,21]

# %%
stats.mode(age_2)#Hepsi tek degerse mod olarak en kucugu alir
# Out:
# ModeResult(mode=array([17]), count=array([1]))

# %%
x=[8,10,5,24,8,3,3,40,7,6,12,4,11]

# %%
q75,q50,q25=np.percentile(x,[75,50,25])

# %%
q75
# Out:
# 11.0

# %%
q50
# Out:
# 8.0

# %%
iqr=q75-q25

# %%
iqr
# Out:
# 6.0

# %%
from scipy.stats import iqr
iqr(x)
# Out:
# 6.0

# %%
import matplotlib.pyplot as plt
mu,sigma=100,40
s=np.random.normal(mu,sigma,100000)
plt.hist(s,100)
plt.xlim(0,240)
# Out:
# (0, 240)

# %%
xx=np.linspace(0,5,11)

# %%
xx
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y=xx**2

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(xx,y)

# %%
plt.scatter(xx,y)

# %%
import seaborn as sns
sns.scatterplot(xx,y)

# %%
sns.jointplot(xx,y, kind='scatter')

# %%
import pandas as pd

# %%
lst=zip(xx,y)
df=pd.DataFrame(lst,columns=['x','y'])
df.head()
# Out:
#      x     y
# 0  0.0  0.00
# 1  0.5  0.25
# 2  1.0  1.00
# 3  1.5  2.25
# 4  2.0  4.00

# %%
df.plot.scatter('x','y')
